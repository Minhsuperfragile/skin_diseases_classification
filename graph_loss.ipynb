# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_json(r"model_eval/overall_loss.json")
data=np.mean(data,axis=0)
data.shape
# Out:
# (5,)

# %%
plt.figure(figsize=(10, 5))
plt.plot(data, label='Loss', color='blue')
plt.title('Loss Graph')
plt.xticks(range(0,5), range(1,6))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()
